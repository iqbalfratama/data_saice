# %%
print("===NO1===")
print("A-xis")
a = 20
b = 75000
c = 300000
xis = ((a * b) + (a * c))
print("maka pengeluaran gaji + asuransi setiap perusahaan adalah " +str(xis) + " RP")
print("B-log")
a = 14
b = 75000
c = 360000
log = ((a * b) + (a * c))
print("maka pengeluaran gaji + asuransi setiap perusahaan adalah " +str(log) + " RP")
print("C-in")
a = 28
b = 75000
c = 475000
cin = ((a * b) + (a * c))
print("maka pengeluaran gaji + asuransi setiap perusahaan adalah " +str(cin) + " RP")
print("D-namic")
a = 42
b = 75000
c = 580000
namic = ((a * b) + (a * c))
print("maka pengeluaran gaji + asuransi setiap perusahaan adalah " +str(namic) + " RP")
print("E-psilon")
a = 18
b = 75000
c = 400000
lon = ((a * b) + (a * c))
print("maka pengeluaran gaji + asuransi setiap perusahaan adalah " +str(lon) + " RP")
print()
print("===NO2===")
pajak = 0.03
as1 = 280000000
as2 = 310000000
as3 = 420000000
as4 = 550000000
as5 = 340000000
la1 = 32500000
la2 = 31000000
la3 = 42000000
la4 = 51500000
la5 = 27000000
ut1 = 0.08
ut2 = 0.04
ut3 = 0.12
ut4 = 0.11
ut5 = 0.03
hasil1 = ((pajak * la1) + (ut1 * as1))
print("maka total pajak A-xis adalah " +str(hasil1) + " RP")
hasil2 = ((pajak * la2) + (ut2 * as2))
print("maka total pajak B-log adalah " +str(hasil2) + " RP")
hasil3 = ((pajak * la3) + (ut3* as3))
print("maka total pajak C-in adalah " +str(hasil3) + " RP")
hasil4 = ((pajak * la4) + (ut4 * as4))
print("maka total pajak D-namic adalah " +str(hasil4) + " RP")
hasil5 = ((pajak * la5) + (ut5 * as5))
print("maka total pajak E-psilon adalah " +str(hasil5) + " RP")
print()
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
usai = ['A-xis','B-log','c-in','D-namic','E-psilon']
orla = [23375000.0,13330000.0,51660000.0,62045000.0,11010000.0]
c = ['orange','yellow', 'blue']
plt.title("TOTAL PAJAK DAN UTANG")
ax.bar(usai,orla, color=c)
plt.show()
print()
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title('TOTAL PAJAK DAN UTANG')
jurusan=['A-xis','B-log','c-in','D-namic','E-psilon']
orla = [23375000.0,13330000.0,51660000.0,62045000.0,11010000.0]
ax.pie(orla,labels=jurusan,autopct='%1.2f%%')

plt.show()
print()
print("===NO3===")
csr1 = 0.025
csr2 = 0.035
as1 = 280000000
as2 = 310000000
as3 = 420000000
as4 = 550000000
as5 = 340000000
hasil1 = (csr1 * as1)
print("maka csr perusahaan adalah : " +str(hasil1) + " RP")
hasil2 = (csr2 * as2)
print("maka csr perusahaan adalah : " +str(hasil2) + " RP")
hasil3 = (csr2 * as3)
print("maka csr perusahaan adalah : " +str(hasil3) + " RP")
hasil4 = (csr2 * as4)
print("maka csr perusahaan adalah : " +str(hasil4) + " RP")
hasil5 = (csr2 * as5)
print("maka csr perusahaan adalah : " +str(hasil5) + " RP")
print()
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
usai = ['A-xis','B-log','c-in','D-namic','E-psilon']
orla = [7000000.0,10850000.000000002,14700000.000000002,19250000.0,11900000.000000002]
c = ['orange','yellow', 'blue']
plt.title(" TOTAL SCR PERUSAHAAN")
ax.bar(usai,orla, color=c)
plt.show()
print()
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title('TOTAL SCR PERUSAHAAN')
jurusan=['A-xis','B-log','c-in','D-namic','E-psilon']
orla = [7000000.0,10850000.000000002,14700000.000000002,19250000.0,11900000.000000002]
ax.pie(orla,labels=jurusan,autopct='%1.2f%%')

plt.show()
print()
print("===NO4===")
lab1 = 32500000 * 12
lab2 = 31000000 * 12
lab3 = 42000000 * 12
lab4 = 51500000 * 12
lab5 = 27000000 * 12
sj = (lab1 + lab2 + lab3 + lab4 + lab5)
print("maka labaa perusahaan adalah 1 " +str(lab1))
print("maka labaa perusahaan adalah 2 " +str(lab2))
print("maka labaa perusahaan adalah 3 " +str(lab3))
print("maka labaa perusahaan adalah 4 " +str(lab4))
print("maka labaa perusahaan adalah 5 " +str(lab5))
print("maka jumlah keseluruhan laba adalah " +str(sj))
print()
print("===NO5===")
lab1 = 32500000
lab2 = 31000000
lab3 = 42000000
lab4 = 51500000 
lab5 = 27000000 

as1= 280000000
as2 = 310000000
as3 = 420000000
as4 = 550000000
as5 = 340000000

csr1 = 0.025
csr2 = 0.035
hasil1 = ((lab1 * 12) - csr1 * as1 - (7500000 * 12) - 23375000)
print("maka total gajih bersih tahunan adalah " +str(hasil1))
hasil2 = ((lab2 * 12) - csr2 * as2 - (6090000 * 12) - 13330000)
print("maka total gajih bersih tahunan adalah " +str(hasil2))
hasil3 = ((lab3 * 12) - csr2 * as3 - (15400000 * 12) - 51660000)
print("maka total gajih bersih tahunan adalah " +str(hasil3))
hasil4 = ((lab4 * 12) - csr2 * as4 - (27510000 * 12) - 62045000)
print("maka total gajih bersih tahunan adalah " +str(hasil4))
hasil5 = ((lab5 * 12) - csr2 * as5 - (8550000* 12) - 11010000)
print("maka total gajih bersih tahunan adalah " +str(hasil5))
print()
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
usai = ['A-xis','B-log','c-in','D-namic','E-psilon']
orla = [269625000.0,274740000.0,252840000.0,206585000.0,198490000.0]
c = ['orange','yellow', 'blue']
plt.title("TOTAL GAJI BERSIH TAHUNAN")
ax.bar(usai,orla, color=c)
plt.show()
print()
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title('TOTAL GAJI BERSIH TAHUNAN')
jurusan=['A-xis','B-log','c-in','D-namic','E-psilon']
orla = [269625000.0,274740000.0,252840000.0,206585000.0,198490000.0]
ax.pie(orla,labels=jurusan,autopct='%1.2f%%')

plt.show()
# Out:
# ===NO1===
# A-xis
# maka pengeluaran gaji + asuransi setiap perusahaan adalah 7500000 RP
# B-log
# maka pengeluaran gaji + asuransi setiap perusahaan adalah 6090000 RP
# C-in
# maka pengeluaran gaji + asuransi setiap perusahaan adalah 15400000 RP
# D-namic
# maka pengeluaran gaji + asuransi setiap perusahaan adalah 27510000 RP
# E-psilon
# maka pengeluaran gaji + asuransi setiap perusahaan adalah 8550000 RP
#
# ===NO2===
# maka total pajak A-xis adalah 23375000.0 RP
# maka total pajak B-log adalah 13330000.0 RP
# maka total pajak C-in adalah 51660000.0 RP
# maka total pajak D-namic adalah 62045000.0 RP
# maka total pajak E-psilon adalah 11010000.0 RP
# ===NO3===
# maka csr perusahaan adalah : 7000000.0 RP
# maka csr perusahaan adalah : 10850000.000000002 RP
# maka csr perusahaan adalah : 14700000.000000002 RP
# maka csr perusahaan adalah : 19250000.0 RP
# maka csr perusahaan adalah : 11900000.000000002 RP
# ===NO4===
# maka labaa perusahaan adalah 1 390000000
# ...
