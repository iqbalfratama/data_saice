# %%
from numpy import UFUNC_BUFSIZE_DEFAULT
#soal no 1
print("===soal 1===")
a = 0
b = 1
c = 4
d = 7
e = 5
f = 0
s2 = (a + b + c + d + e + f)
print("maka jumlah orang di setiap tingkatan pendidikan S2 adalah : " + str(s2))
print()
a = 4
b = 12
c = 6
d = 13
e = 14
f = 0
s1 = (a + b + c + d + e + f)
print("maka jumlah orang di setiap tingkatan pendidikan S1 adalah : " + str(s1))
print()
a = 12
b = 17
c = 5
d = 20
e = 11
f = 75
sma = (a + b + c + d + e + f)
print("maka jumlah orang di setiap tingkatan pendidikan SMA adalah : " + str(sma))
print()
a = 5
b = 6
c = 15
d = 9
e = 20
f = 15
smp = (a + b + c + d + e + f)
print("maka jumlah orang di setiap tingkatan pendidikan SMP adalah : " + str(smp))
print()
a = 1	
b = 8	
c = 0	
d = 19	
e = 10	
f = 1	
sd = (a + b + c + d + e + f)
print("maka jumlah orang di setiap tingkatan pendidikan SD adalah : " + str(sd))
print()
a = 2
b = 14
c = 3
d = 10
e = 0
f = 1
tdk = (a + b + c + d + e + f)
print("maka jumlah orang di setiap tingkatan pendidikan Tidak Di Ketahui adalah : " + str(tdk))
print("===soal 2===")
S2a = 	0.25
S1s = 	0.20
SMA = 0.15
SMP =	0.10
SD =	0.05
tdki = 0.03
print("maka index s2 adalah : " + str(s2 * S2a))
print("maka index s1 adalah : " + str(s1 * S1s))
print("maka index SMA adalah : " + str(sma * SMA))
print("maka index SMP adalah : " + str(smp * SMP))
print("maka index SD adalah : " + str(sd * SD))
print("maka index Tidak Di Ketahui adalah : " + str(tdk * tdki))

print()
S2 = 0.25
S1 = 0.20
SMA = 0.15
SMP = 0.10
SD = 0.5
TDK = 0.3
print("S2")
a1 = 0 * S2
b1 = 4 * S1	
c1 = 12* SMA
d1= 5 * SMP
e1 = 1	* SD
f1 = 2 * TDK
print("bobot S2 70 adalah : " + str(a1))
print("bobot S1 70 adalah : " + str(b1))
print("bobot SMA 70 adalah : " + str(c1))
print("bobot SMK 70 adalah : " + str(d1))
print("bobot SD 70 adalah : " + str(e1))
print("bobot TDK 70 adalah : " + str(f1))
print("maka jumlah keselurhan adalah : " + str(a1+b1+c1+d1+e1+f1))
print()
a2 = 1 * S2
b2 = 12 * S1	
c2 = 17 * SMA
d2 = 6 * SMP
e2 = 8	* SD
f2 = 14 * TDK
print("bobot S2 60 adalah : " + str(a2))
print("bobot S1 60 adalah : " + str(b2))
print("bobot SMA 60 adalah : " + str(c2))
print("bobot SMP 60 adalah : " + str(d2))
print("bobot SD 60 adalah : " + str(e2))
print("bobot TDK 60 adalah : " + str(f2))
print("maka jumlah keselurhan adalah : " + str(a2+b2+c2+d2+e2+f2))
print()
a3 = 4 * S2
b3 = 6 * S1	
c3 = 5 * SMA
d3 = 15 * SMP
e3 = 0	* SD
f3 = 3 * TDK
print("bobot 50 adalah : " + str(a3))
print("bobot 50 adalah : " + str(b3))
print("bobot 50 adalah : " + str(c3))
print("bobot 50 adalah : " + str(d3))
print("bobot 50 adalah : " + str(e3))
print("bobot 50 adalah : " + str(f3))
print("maka jumlah keselurhan adalah : " + str(a3+b3+c3+d3+e3+f3))
print()
a4 = 7 * S2
b4 = 13* S1	
c4 = 20 * SMA
d4 = 9 * SMP
e4 = 19	* SD
f4 = 10 * TDK
print("bobot 40 adalah : " + str(a4))
print("bobot 40 adalah : " + str(b4))
print("bobot 40 adalah : " + str(c4))
print("bobot 40 adalah : " + str(d4))
print("bobot 40 adalah : " + str(e4))
print("bobot 40 adalah : " + str(f4))
print("maka jumlah keselurhan adalah : " + str(a4+b4+c4+d4+e4+f4))
print()
a5 = 5 * S2
b5 = 14* S1	
c5 = 11 * SMA
d5 = 20 * SMP
e5 = 10	* SD
f5 = 0 * TDK
print("bobot 30 adalah : " + str(a5))
print("bobot 30 adalah : " + str(b5))
print("bobot 30 adalah : " + str(c5))
print("bobot 30 adalah : " + str(d5))
print("bobot 30 adalah : " + str(e5))
print("bobot 30 adalah : " + str(f5))
print("maka jumlah keselurhan adalah : " + str(a5+b5+c5+d5+e5+f5))
print()
a6 = 0 * S2
b6 = 0* S1	
c6 = 75 * SMA
d6 = 15 * SMP
e6 = 1	* SD
f6 = 1 * TDK
print("bobot 20 adalah : " + str(a6))
print("bobot 20 adalah : " + str(b6))
print("bobot 20 adalah : " + str(c6))
print("bobot 20 adalah : " + str(d6))
print("bobot 20 adalah : " + str(e6))
print("bobot 20 adalah : " + str(f6))
print("maka jumlah keselurhan adalah : " + str(a6+b6+c6+d6+e6+f6))
print()

print("SOAL NO 5")
print()
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
usai = ['70', '60', '50', '40', '30', '20']
orla = [24, 58, 33, 78, 60, 92]
c = ['orange','yellow', 'blue']
plt.title("JUMLAH ORANG DI SETIAP PENDIDIKAN")
ax.bar(usai,orla, color=c)
plt.show()
print()

import matplotlib.pyplot as plt
#pie chart

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
usia = ['70', '60', '50', '40', '30', '20']
jmh_orang = [24, 58, 33, 78, 60, 92]
ax.pie(usia,labels=jmh_orang,autopct='%1.2f%%')
plt.title("JUMLAH ORANG DI SETIAP PENDIDIKAN")
plt.show()

print()
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
usaiy = ['70', '60', '50', '40', '30', '20']
bobot = [4.19, 14.0, 5.35, 20.75, 12.7, 13.55]
c = ['orange','yellow', 'blue']
plt.title("BOBOT TIAP TAHUNNYAH")
ax.bar(usaiy,bobot, color=c)
plt.show()
print()

import matplotlib.pyplot as plt
#pie chart

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
usi = ['70', '60', '50', '40', '30', '20']
babot = [4.19, 14.0, 5.35, 20.75, 12.7, 13.55]
ax.pie(usi,labels=babot,autopct='%1.2f%%')
plt.title("BOBOT TIAP TAHUNNYAH")
plt.show()
# Out:
# ===soal 1===
# maka jumlah orang di setiap tingkatan pendidikan S2 adalah : 17
#
# maka jumlah orang di setiap tingkatan pendidikan S1 adalah : 49
#
# maka jumlah orang di setiap tingkatan pendidikan SMA adalah : 140
#
# maka jumlah orang di setiap tingkatan pendidikan SMP adalah : 70
#
# maka jumlah orang di setiap tingkatan pendidikan SD adalah : 39
#
# maka jumlah orang di setiap tingkatan pendidikan Tidak Di Ketahui adalah : 30
# ===soal 2===
# maka index s2 adalah : 4.25
# maka index s1 adalah : 9.8
# maka index SMA adalah : 21.0
# maka index SMP adalah : 7.0
# maka index SD adalah : 1.9500000000000002
# maka index Tidak Di Ketahui adalah : 0.8999999999999999
#
# S2
# bobot S2 70 adalah : 0.0
# bobot S1 70 adalah : 0.8
# bobot SMA 70 adalah : 1.7999999999999998
# bobot SMK 70 adalah : 0.5
# bobot SD 70 adalah : 0.5
# bobot TDK 70 adalah : 0.6
# maka jumlah keselurhan adalah : 4.199999999999999
#
# bobot S2 60 adalah : 0.25
# bobot S1 60 adalah : 2.4000000000000004
# ...
